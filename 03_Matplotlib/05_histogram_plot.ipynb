# %% [markdown]
# Histogram
# x=[]
# plt.hist()
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x=np.random.randint(10,60,50)
print(x)
# Out:
# [16 11 53 15 23 26 56 29 49 35 56 26 57 29 52 22 15 20 52 51 54 26 54 19
#  11 14 23 35 13 28 28 59 47 58 30 57 40 20 14 59 36 42 51 37 54 59 44 41
#  46 34]

# %%
x1=[52, 20 ,26 ,56 ,42 ,51 ,30 ,46 ,35 ,31 ,41 ,34 ,39 ,55 ,48 ,47 ,28 ,46 ,17 ,19 ,29 ,43 ,26 ,29,
 16, 46, 47 ,27 ,31 ,44 ,51 ,47 ,15 ,59,46 ,32 ,56 ,13 ,38 ,49 ,34 ,23 ,54 ,52 ,24 ,32 ,14 ,51,
 15 ,53]
plt.hist(x1,color="r",edgecolor="b")
plt.title("histogram")
plt.xlabel("python")
plt.ylabel("no")
plt.show()

# %%
x1=[52, 20 ,26 ,56 ,42 ,51 ,30 ,46 ,35 ,31 ,41 ,34 ,39 ,55 ,48 ,47 ,28 ,46 ,17 ,19 ,29 ,43 ,26 ,29,
 16, 46, 47 ,27 ,31 ,44 ,51 ,47 ,15 ,59,46 ,32 ,56 ,13 ,38 ,49 ,34 ,23 ,54 ,52 ,24 ,32 ,14 ,51,
 15 ,53]
l=[10,20,30,40,50,60]
plt.hist(x1,color="r",edgecolor="b",bins=l)
plt.title("histogram")
plt.xlabel("python")
plt.ylabel("no")
plt.show()

# %%
x1=[52, 20 ,26 ,56 ,42 ,51 ,30 ,46 ,35 ,31 ,41 ,34 ,39 ,55 ,48 ,47 ,28 ,46 ,17 ,19 ,29 ,43 ,26 ,29,
 16, 46, 47 ,27 ,31 ,44 ,51 ,47 ,15 ,59,46 ,32 ,56 ,13 ,38 ,49 ,34 ,23 ,54 ,52 ,24 ,32 ,14 ,51,
 15 ,53]
l=[10,20,30,40,50,60]
plt.hist(x1,"auto",(0,100),edgecolor="b")
plt.title("histogram")
plt.xlabel("python")
plt.ylabel("no")
plt.show()
# Out:
# C:\Users\Jayas\AppData\Local\Temp\ipykernel_10900\2498509255.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(x1,"auto",(0,100),edgecolor="b")

# %%
x1=[52, 20 ,26 ,56 ,42 ,51 ,30 ,46 ,35 ,31 ,41 ,34 ,39 ,55 ,48 ,47 ,28 ,46 ,17 ,19 ,29 ,43 ,26 ,29,
 16, 46, 47 ,27 ,31 ,44 ,51 ,47 ,15 ,59,46 ,32 ,56 ,13 ,38 ,49 ,34 ,23 ,54 ,52 ,24 ,32 ,14 ,51,
 15 ,53]
l=[10,20,30,40,50,60]
plt.hist(x1,"auto",(0,100),edgecolor="b",cumulative=-1)
plt.title("histogram")
plt.xlabel("python")
plt.ylabel("no")
plt.show()
# Out:
# C:\Users\Jayas\AppData\Local\Temp\ipykernel_10900\3689507088.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(x1,"auto",(0,100),edgecolor="b",cumulative=-1)

# %%
x1=[52, 20 ,26 ,56 ,42 ,51 ,30 ,46 ,35 ,31 ,41 ,34 ,39 ,55 ,48 ,47 ,28 ,46 ,17 ,19 ,29 ,43 ,26 ,29,
 16, 46, 47 ,27 ,31 ,44 ,51 ,47 ,15 ,59,46 ,32 ,56 ,13 ,38 ,49 ,34 ,23 ,54 ,52 ,24 ,32 ,14 ,51,
 15 ,53]
l=[10,20,30,40,50,60]
plt.hist(x1,"auto",(0,100),edgecolor="b",bottom=20)
plt.title("histogram")
plt.xlabel("python")
plt.ylabel("no")
plt.show()
# Out:
# C:\Users\Jayas\AppData\Local\Temp\ipykernel_10900\3845223022.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(x1,"auto",(0,100),edgecolor="b",bottom=20)

# %%
x1=[52, 20 ,26 ,56 ,42 ,51 ,30 ,46 ,35 ,31 ,41 ,34 ,39 ,55 ,48 ,47 ,28 ,46 ,17 ,19 ,29 ,43 ,26 ,29,
 16, 46, 47 ,27 ,31 ,44 ,51 ,47 ,15 ,59,46 ,32 ,56 ,13 ,38 ,49 ,34 ,23 ,54 ,52 ,24 ,32 ,14 ,51,
 15 ,53]
l=[10,20,30,40,50,60]
plt.hist(x1,color="r",edgecolor="b",bins=l,align="left")
plt.title("histogram")
plt.xlabel("python")
plt.ylabel("no")
plt.show()

# %%
x1=[52, 20 ,26 ,56 ,42 ,51 ,30 ,46 ,35 ,31 ,41 ,34 ,39 ,55 ,48 ,47 ,28 ,46 ,17 ,19 ,29 ,43 ,26 ,29,
 16, 46, 47 ,27 ,31 ,44 ,51 ,47 ,15 ,59,46 ,32 ,56 ,13 ,38 ,49 ,34 ,23 ,54 ,52 ,24 ,32 ,14 ,51,
 15 ,53]
l=[10,20,30,40,50,60]
plt.hist(x1,color="r",edgecolor="b",bins=l,align="left",histtype="step")#histype=stepfilled,barstacked,bar
plt.title("histogram")
plt.xlabel("python")
plt.ylabel("no")
plt.show()

# %%
x1=[52, 20 ,26 ,56 ,42 ,51 ,30 ,46 ,35 ,31 ,41 ,34 ,39 ,55 ,48 ,47 ,28 ,46 ,17 ,19 ,29 ,43 ,26 ,29,
 16, 46, 47 ,27 ,31 ,44 ,51 ,47 ,15 ,59,46 ,32 ,56 ,13 ,38 ,49 ,34 ,23 ,54 ,52 ,24 ,32 ,14 ,51,
 15 ,53]
l=[10,20,30,40,50,60]
plt.hist(x1,color="r",edgecolor="b",bins=l,align="left",orientation="horizontal")
plt.title("histogram")
plt.xlabel("python")
plt.ylabel("no")
plt.show()

# %%
x1=[52, 20 ,26 ,56 ,42 ,51 ,30 ,46 ,35 ,31 ,41 ,34 ,39 ,55 ,48 ,47 ,28 ,46 ,17 ,19 ,29 ,43 ,26 ,29,
 16, 46, 47 ,27 ,31 ,44 ,51 ,47 ,15 ,59,46 ,32 ,56 ,13 ,38 ,49 ,34 ,23 ,54 ,52 ,24 ,32 ,14 ,51,
 15 ,53]
l=[10,20,30,40,50,60]
plt.hist(x1,color="r",edgecolor="b",bins=l,align="left",orientation="horizontal",rwidth=.5,label="hist plot")
plt.title("histogram")
plt.xlabel("python")
plt.ylabel("no")
plt.legend()
plt.show()

# %%
x1=[52, 20 ,26 ,56 ,42 ,51 ,30 ,46 ,35 ,31 ,41 ,34 ,39 ,55 ,48 ,47 ,28 ,46 ,17 ,19 ,29 ,43 ,26 ,29,
 16, 46, 47 ,27 ,31 ,44 ,51 ,47 ,15 ,59,46 ,32 ,56 ,13 ,38 ,49 ,34 ,23 ,54 ,52 ,24 ,32 ,14 ,51,
 15 ,53]
l=[10,20,30,40,50,60]
plt.hist(x1,color="r",edgecolor="b",bins=l,align="left",rwidth=.5,label="hist plot")
plt.title("histogram")
plt.xlabel("python")
plt.ylabel("no")
plt.axvline(45,color="g",label="line")
plt.legend()
plt.grid()
plt.show()
