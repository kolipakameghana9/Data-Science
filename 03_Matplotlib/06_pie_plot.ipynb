# %%
Pie Plot
x=[]
plt.pie()
plt.show

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40]
y=["c","c++","java","python"]
plt.pie(x)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.3,.0,.0,.0]
plt.pie(x,labels=y,explode=ex)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.3,.0,.0,.0]
c=["r","g","m","b"]
plt.pie(x,labels=y,explode=ex,colors=c)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.3,.0,.0,.0]
c=["r","g","m","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%.1f%%")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.3,.0,.0,.0]
c=["r","g","m","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%.1f%%",shadow=True)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.3,.0,.0,.0]
c=["r","g","m","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%.1f%%",shadow=True,radius=1.5,labeldistance=.8)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.3,.0,.0,.0]
c=["r","g","m","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%.1f%%",shadow=True,radius=1.5,labeldistance=.8,startangle=180)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.3,.0,.0,.0]
c=["r","g","m","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%.1f%%",shadow=True,radius=1.5,labeldistance=.8,textprops={"fontsize":15},wedgeprops={"linewidth":10,"edgecolor":"y"})
plt.show()

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.3,.0,.0,.0]
c=["r","g","m","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%.1f%%",radius=1,labeldistance=.8,textprops={"fontsize":10},wedgeprops={"linewidth":10,},rotatelabels=True)
plt.title("pie plot")
plt.legend(loc=2)
plt.show()

# %% [markdown]
# Dot Pie Plot

# %%
plt.pie([1])
plt.show()

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
x1=[40,30,20,10]
ex=[0.3,.0,.0,.0]
c=["r","g","m","b"]
plt.pie(x,labels=y,radius=2)
plt.pie(x1,labels=y,radius=1)
plt.title("pie plot")

plt.show()

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
x1=[40,30,20,10]
ex=[0.3,.0,.0,.0]
c=["r","g","m","b"]
plt.pie(x,labels=y,radius=2)
plt.pie([1],colors="w")
plt.title("pie plot")

plt.show()

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
x1=[40,30,20,10]
ex=[0.3,.0,.0,.0]
c=["r","g","m","b"]
plt.pie(x,labels=y,radius=1)
cr=plt.Circle(xy=(0,0),radius=.5,facecolor="w")
plt.gca().add_artist(cr)

plt.title("pie plot")

plt.show()
