# %% [markdown]
# Histogram plot
# df=sns.load_dataset("")
# sns.distplot(df[""])
# plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=sns.load_dataset("penguins")
print(x)

# %%
sns.histplot(df["island"])
plt.show()

# %%
sns.histplot(df["bill_length_mm"],bins=[35,40,45,50,55,60])
plt.show()

# %%
sns.histplot(df["bill_length_mm"],bins=[35,40,45,50,55,60],kde=True,color="r")#kernel density estimator,#use rug #use log_scale=true
plt.show()
